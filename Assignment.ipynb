# %%
pip install bokeh
# Out:
# ...
#
# ...

# %% [markdown]
# Q1. How can you create a Bokeh plot using Python code?

# %% [markdown]
# Bokeh is a Python interactive visualization library that targets modern web browsers for presentation. You can create Bokeh plots using Python code by following these steps:

# %%
from bokeh.plotting import figure, show

# Create data
x = [1, 2, 3, 4, 5]
y = [6, 7, 2, 4, 5]

# Create a Bokeh figure
p = figure(title='My Bokeh Plot', x_axis_label='X-axis', y_axis_label='Y-axis')

# Add glyphs to the plot
p.circle(x, y, size=10, color='navy', alpha=0.5)

# Show the plot
show(p)

# %% [markdown]
# Q2. What are glyphs in Bokeh, and how can you add them to a Bokeh plot? Explain with an example.

# %% [markdown]
# In Bokeh, glyphs are visual markers used to represent data points on a plot. Glyphs can take various forms, such as circles, squares, lines, and more. They are the building blocks of Bokeh plots and are added to a figure to visually represent the data.
#
# Here's a simple example demonstrating how to add glyphs to a Bokeh plot using circles:

# %%
from bokeh.plotting import figure, show

# Create data
x = [1, 2, 3, 4, 5]
y = [6, 7, 2, 4, 5]

# Create a Bokeh figure
p = figure(title='Glyphs Example', x_axis_label='X-axis', y_axis_label='Y-axis')

# Add a circle glyph to the plot
p.circle(x, y, size=10, color='navy', alpha=0.5)

# Show the plot
show(p)

# %% [markdown]
# In this example:
#
# Customizing Axes:
#
# xaxis and yaxis attributes are used to customize axis properties.
#
# axis_label_text_font_style sets the font style of the axis labels.
#
# axis_label_text_color sets the color of the axis labels.
#
# Customizing Title:
#
# title attribute is used to customize title properties.
#
# text_color sets the color of the title.
#
# text_font_size sets the font size of the title.
#
# Customizing Legend:
#
# Legend is created separately, specifying items and location.
#
# add_layout method is used to add the legend to the plot.

# %% [markdown]
# Q3. How can you customize the appearance of a Bokeh plot, including the axes, title, and legend?

# %%
from bokeh.plotting import figure, show
from bokeh.models import Legend

# Create data
x = [1, 2, 3, 4, 5]
y1 = [6, 7, 2, 4, 5]
y2 = [8, 5, 3, 7, 2]

# Create a Bokeh figure
p = figure(title='Customized Bokeh Plot', x_axis_label='X-axis', y_axis_label='Y-axis')

# Add line glyphs to the plot
line1 = p.line(x, y1, line_width=2, line_color='blue', legend_label='Line 1')
line2 = p.line(x, y2, line_width=2, line_color='red', legend_label='Line 2')

# Customize axes
p.xaxis.axis_label_text_font_style = 'italic'
p.yaxis.axis_label_text_color = 'green'

# Customize title
p.title.text_color = 'purple'
p.title.text_font_size = '20px'

# Customize legend
legend = Legend(items=[
    ("Line 1", [line1]),
    ("Line 2", [line2]),
], location='top_left')

p.add_layout(legend)

# Show the plot
show(p)

# %% [markdown]
# Q4. What is a Bokeh server, and how can you use it to create interactive plots that can be updated in
# real time?

# %% [markdown]
# A Bokeh server is a component of the Bokeh library that allows you to create interactive web applications with live, real-time updates. Bokeh server applications can push updates to the connected clients, enabling dynamic and interactive visualizations that respond to user input or changes in data.

# %%
# my_bokeh_app.py

from bokeh.plotting import figure, curdoc
from bokeh.models import ColumnDataSource
import numpy as np
import time

# Function to create Bokeh plot
def create_plot():
    x = np.linspace(0, 4 * np.pi, 100)
    y = np.sin(x)

    source = ColumnDataSource(data=dict(x=x, y=y))

    plot = figure(title='Real-time Sinusoidal Plot')
    plot.line('x', 'y', source=source, line_width=2)

    return plot

# Update function for real-time updates
def update():
    while True:
        x = np.linspace(0, 4 * np.pi, 100)
        y = np.sin(x + time.time())

        # Update data source
        source.data = dict(x=x, y=y)

        # Sleep for a short interval (e.g., 0.1 seconds)
        time.sleep(0.1)

# Create Bokeh plot
plot = create_plot()

# Add the plot to the current document
curdoc().add_root(plot)

# Start the real-time update function
update()

# %% [markdown]
# Q5. How can you embed a Bokeh plot into a web page or dashboard using Flask or Django?

# %% [markdown]
# Embedding a Bokeh plot into a web page or dashboard using Flask or Django involves using the Bokeh server to create the plot and then integrating it with the respective web framework

# %%
# # app.py
# from flask import Flask, render_template
# from bokeh.embed import server_document

# app = Flask(__name__)

# @app.route('/')
# def index():
#     # Specify the Bokeh server URL
#     bokeh_script = server_document('http://localhost:5006/bokeh_app')

#     return render_template('index.html', bokeh_script=bokeh_script)

# if __name__ == '__main__':
#     app.run(debug=True)

# %%
# <!-- templates/index.html -->
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>Bokeh Plot with Flask</title>
# </head>
# <body>
#     <h1>Bokeh Plot</h1>
#     {{ bokeh_script|safe }}
# </body>
# </html>

# %%
from IPython.display import Image
Image('G:/DATA SCIENCE PW SKILLS/003 ASSIGNMENTS/Week 9/5/Screenshot.png')
